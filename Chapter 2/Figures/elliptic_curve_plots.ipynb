# %%
plot(EllipticCurve([12, 217]), xmax=20, ymax=60, ymin=-60, transparent=True) # dpi=2000)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(EllipticCurve(GF(419),[12, 217]), transparent=True) # dpi = 2000)
# Out:
# Graphics object consisting of 1 graphics primitive
