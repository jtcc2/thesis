# %% [markdown]
# Distance distributions

# %%
load("utils.sage")
from sage.graphs.distances_all_pairs import distances_all_pairs

p = 2689
Ls = [2]

# Get isogeny graph, and adjacency matrix
G = get_L_graph(p, Ls)

# We may find distances between all pairs of vertices
pairwise_distances = distances_all_pairs(G)

# Or alternatively obtain distance distribution
distance_distribution = G.distances_distribution()
distance_distribution
# Out:
# {1: 3/223,
#  2: 83/3122,
#  3: 183/3568,
#  4: 2361/24976,
#  5: 1943/12488,
#  6: 5455/24976,
#  7: 6057/24976,
#  8: 553/3568,
#  9: 499/12488,
#  10: 67/24976}

# %%
# A visual representation of distance distributions

import matplotlib.pyplot as plt

plt.plot(*zip(*sorted(distance_distribution.items())))
plt.show()
